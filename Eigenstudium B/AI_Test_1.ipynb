# %%
# Frage 2
desired_as_desired = 189
spam_as_desired = 1
desired_as_spam = 11
spam_as_spam = 799

correct = desired_as_desired + spam_as_spam
print(f"Korrekt klassifizierte Emails: {correct}")

incorrect = spam_as_desired + desired_as_spam
print(f"Falsch klassifizierte Emails: {incorrect}")

cost_spam_delivered = spam_as_desired * 1
cost_desired_spammed = desired_as_spam * 10

total_cost = cost_spam_delivered + cost_desired_spammed
print(f"Gesamtkosten: {total_cost} Cent")
# Out:
# Korrekt klassifizierte Emails: 988
# Falsch klassifizierte Emails: 12
# Gesamtkosten: 111 Cent

# %%
a = [39, 40, 45, 13, 7, 28, 22, 35, 24, 26, 21, 31, 32, 28, 22, 35, 24, 26, 62, 21, 31, 32]
b = [3, 40, 28, 10, 46, 20, 31, 29]

merged_list = list(set(a).union(set(b)))
len_merged = len(merged_list)

print("Length: ", len_merged)

max_val = max(26, 35, 62)

print(max_val)

dic1 = {1: 10, 2: 20}
dic2 = {1: 20, 3: 40}
dic3 = {2: 50, 6: 60}

merged_dic = {}
merged_dic.update(dic1)
merged_dic.update(dic2)
merged_dic.update(dic3)

val_key_1 = merged_dic[1]
print("Key 1: ", val_key_1)
# Out:
# Length:  19
# 62
# Key 1:  20
